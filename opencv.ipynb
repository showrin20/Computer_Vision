# %%
import cv2 as cv

# Reading images

# img = cv.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg")

# cv.imshow('image',img)
# cv.waitKey(0)
# cv.destroyAllWindows()

#Reading videos

# capture = cv.VideoCapture("F:\WhatsApp Video 2021-06-18 at 12.03.45 AM.mp4")

# while True:
#     ret, frame = capture.read()

#     cv.imshow('video',frame)

#     if cv.waitKey(20) & 0xFF == ord('d'):
#         break

# capture.release()
# cv.destroyAllWindows()

# %%
#converting to grayscale
import cv2

img = cv2.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg")
# cv2.imshow('image',img)

# gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# cv2.imshow('gray',gray)



# converting to blur
blur = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)
# cv2.imshow('blur',blur)


# edge cascade(finding edges)
cany = cv2.Canny(blur,125,175)
cv2.imshow('edges',cany)



# dilate image
dilated = cv2.dilate(cany,(7,7),iterations=3)
cv2.imshow('dilated',dilated)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Resizing

import cv2 as cv



def rescaleFrame(frame,scale= 0.75):
    #Live Video, image,stock video
    height = int(frame.shape[0]*scale)
    width = int(frame.shape[1]*scale)

    dimension = (width,height)

    return cv.resize(frame,dimension,interpolation=cv.INTER_AREA)


def ChangeRes(width,height):
    #Live Video
    capture.set(3,width)
    capture.set(4,height)


#Resizing Image

# img = cv.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg")

# cv.imshow('image',img)

# resized_image = rescaleFrame(img)

# cv.imshow('Resized image',resized_image)

# cv.waitKey(0) & 0xFF




#Resizing videos

capture = cv.VideoCapture('F:\WhatsApp Video 2021-06-18 at 12.03.45 AM.mp4')

def ChangeRes(width,height):
    #Jhamela aseee
    global capture
    capture.set(3,width)
    capture.set(4,height)
    print(capture.get(3))
    print(capture.get(4))

while True:
    ret, frame = capture.read()
    frame_resized = ChangeRes(240,460)

    cv.imshow('video',frame)
    
    cv.imshow('video resized',rescaleFrame(frame))

    if cv.waitKey(20) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows()

# %%
# Drawing
from operator import imod
import cv2 as cv
import matplotlib.pyplot as mt
import numpy as np

blank = np.zeros((500,500,3),dtype='uint8')  #width, height, color channels

# cv.imshow('blank',blank)

# 1. Paint the image in certain color

# blank[200:300,300:400] = 0,0,255   #[y axis, x axis] origin at top left
# cv.imshow('Green',blank)



# 2. Draw a rectangle

# cv.rectangle(blank,(0,0),(500,250),(0,255,0),-1)
# cv.imshow('rectangle',blank)

# mt.imshow(blank)
# mt.show()

# cv.rectangle(blank,(0,0),(blank.shape[1]//4,blank.shape[0]//2),(0,255,0),-1)   #shape[1] = width, shape[0] = height
# cv.imshow('quarter square',blank)




# 3. Draw a circle

# cv.circle(blank,(blank.shape[1]//2,blank.shape[0]//2),40,(0,0,255),-1)
# cv.imshow('circle',blank)




# 4. Draw a line

# cv.line(blank,(0,0),(100,100),(255,0,0),4)
# cv.imshow('line',blank)



# 5. Put text

# cv.putText(blank,"Hello",(225,225),cv.FONT_HERSHEY_SIMPLEX,1.0,(0,255,0),2,cv.LINE_AA)
# # cv.imshow('text',blank)

# cv.putText(blank,"World",(350,225),cv.FONT_HERSHEY_SIMPLEX,1.0,(0,255,0),2,cv.LINE_4)
# # cv.imshow('t0',blank)

# cv.putText(blank,"Hi",(100,225),cv.FONT_HERSHEY_SIMPLEX,1.0,(0,255,0),2,cv.LINE_8)
# cv.imshow('text',blank)




# img = cv.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg")
# cv.imshow("image",img)

cv.waitKey(0)
# Out:
# -1

# %%
# Setting camera parameter

import cv2

cap = cv2.VideoCapture(0)

print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

cap.set(3, 1000)  #3 = width 4  = height
cap.set(4, 800)

print(cap.get(3))
print(cap.get(4))

while(cap.isOpened()) :
    ret, frame = cap.read()
    if ret == True:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame', gray)
        if cv2.waitKey(20) & 0XFF == ord('q'):
            break
    else:
        break
cap.release ()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0
# 1280.0
# 720.0

# %%
#show date time


import cv2
from datetime import datetime as dt

cap = cv2.VideoCapture(0)

width = str(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = str(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# cap.set(3, 3000)  #3 = width 4  = height
# cap.set(4, 3000)

# print(cap.get(3))
# print(cap.get(4))

while(cap.isOpened()) :
    ret, frame = cap.read()
    if ret == True:
        # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        text = "Date: "+str(dt.today().strftime("%d-%b-%y"))+ ", Time: "+ str(dt.today().strftime("%I:%M %p"))
        
        cv2.putText(frame,text,(10,50),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2,cv2.LINE_AA)
        
        cv2.imshow('frame', frame)
        if cv2.waitKey(1) & 0XFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#handle mouse events

import cv2,numpy as np

def click_event(event,x,y,flags,param):
    
    #left click
    if event == cv2.EVENT_LBUTTONDOWN:
        text = str(x)+", "+str(y)
        font = cv2.FONT_HERSHEY_SIMPLEX
        
        cv2.putText(img,text,(x,y),font,0.5,(255,255,255),1,cv2.LINE_AA)
        cv2.imshow("image",img)
    
    #right click
    if event == cv2.EVENT_RBUTTONDOWN:
        blue = img[y,x,0]     # y,x as np.zeroes takes row and column sequentially and y is row num,but image uses ,width,height
        green = img[y,x,1]  #img is in BGR format
        red = img[y,x,2]
        
        text = str(blue)+", "+str(green)+", "+str(red)
        font = cv2.FONT_HERSHEY_SIMPLEX
        
        cv2.putText(img,text,(x,y),font,0.5,(150,186,52),1,cv2.LINE_AA)
        cv2.imshow("image",img)
        
    

# img = np.zeros((512,512,3),dtype='uint8')
img = cv2.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg",1)
cv2.imshow('image',img)

cv2.setMouseCallback('image',click_event)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#more mouse events


#Drawing line from one click to other

import cv2,numpy as np
prev = ''
def click_event(event,x,y,flags,param):
    
    #left click
    if event == cv2.EVENT_LBUTTONDOWN:
        global prev
        cv2.circle(img,(x,y),3,(0,0,255),-1)
        if prev != '':
            cv2.line(img,prev,(x,y),(0,0,255),3)
        cv2.imshow("image",img)
        prev = (x,y)
    
        
    

img = np.zeros((512,512,3),dtype='uint8')
# img = cv2.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg",1)
cv2.imshow('image',img)

cv2.setMouseCallback('image',click_event)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Showing color at a point on another window

import cv2,numpy as np

x_coor = 10
y_coor = 50
# def click_event(event,x,y,flags,param):
    
#     if event==cv2.EVENT_LBUTTONDOWN:
#         color = img[y,x,0],img[y,x,1],img[y,x,2]
#         global x_coor,y_coor
#         cv2.putText(win2,"Color:"+str(color),(x_coor,y_coor),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),2)
#         y_coor+=30
#         cv2.imshow('win2',win2)

def click_event (event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        blue = img[y, x, 0]
        green = img [y, x,1]
        red = img [y, x, 2]
        cv2.circle (img, (x, y), 3, (0, 0, 255), -1)
        
        mycolorImage =np.zeros((512, 512, 3), np.uint8)
        mycolorImage [:] = [blue, green, red]
        cv2.imshow('color', mycolorImage)
        
win2 = np.zeros((512,512,3),np.uint8)

img = cv2.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\lena.jpg",1)
# win2 = np.zeros((512,512,3),dtype='uint8')
cv2.imshow('image',img)

cv2.setMouseCallback('image',click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# splitting and merging color channels

import cv2

img = cv2.imread("E:\Prog stuffs\Python Stuffs\OpenCV\opencv-4.x\samples\data\squirrel_cls.jpg")

print(img.shape)
print(img.size)
print(img.dtype)

b,g,r =cv2.split(img)

# cv2.imshow('blue',b)
# cv2.imshow('green',g)
# cv2.imshow('red',r)

hello = cv2.merge((b,g,r))

cv2.imshow("merged",hello)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (426, 535, 3)
# 683730
# uint8

# %%
# Bitwise operation
import cv2
import numpy as np

img1 = np.zeros((250,500,3),np.uint8)
img1 = cv2.rectangle(img1,(200,0),(300,100),(255,255,255),-1)

img2 = np.zeros((250,500,3),())
cv2.imshow('image',img1)

cv2.waitKey(0)
cv2.destroyAllWindows()
